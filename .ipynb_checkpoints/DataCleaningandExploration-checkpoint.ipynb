# %% [markdown]
# # Import Required Libraries Pandas, Numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# ...

# %% [markdown]
# # Data Cleaning and Exploration

# %%
churn_df = pd.read_csv("train.csv")
test_df= pd.read_csv("test.csv")
churn_df.head()
# Out:
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
# 3            No     Fiber optic             No  ...               No
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
churn_df.describe()
# Out:
#                   id  SeniorCitizen         tenure  MonthlyCharges  \
# count  594194.000000  594194.000000  594194.000000   594194.000000
# mean   297096.500000       0.114102      36.577258       65.866223
# std    171529.177263       0.317936      25.061922       31.067444
# min         0.000000       0.000000       1.000000       18.250000
# 25%    148548.250000       0.000000      12.000000       29.900000
# 50%    297096.500000       0.000000      35.000000       74.100000
# 75%    445644.750000       0.000000      62.000000       90.800000
# max    594193.000000       1.000000      72.000000      118.750000
#
#         TotalCharges
# count  594194.000000
# mean     2494.377057
# std      2353.916710
# min        18.800000
# 25%       639.650000
# 50%      1433.650000
# 75%      4263.800000
# max      8684.800000

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594194 entries, 0 to 594193
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                594194 non-null  int64
#  1   gender            594194 non-null  object
#  2   SeniorCitizen     594194 non-null  int64
#  3   Partner           594194 non-null  object
#  4   Dependents        594194 non-null  object
#  5   tenure            594194 non-null  int64
#  6   PhoneService      594194 non-null  object
#  7   MultipleLines     594194 non-null  object
#  8   InternetService   594194 non-null  object
#  9   OnlineSecurity    594194 non-null  object
#  10  OnlineBackup      594194 non-null  object
#  11  DeviceProtection  594194 non-null  object
#  12  TechSupport       594194 non-null  object
#  13  StreamingTV       594194 non-null  object
#  14  StreamingMovies   594194 non-null  object
#  15  Contract          594194 non-null  object
# ...

# %%
### check for missing values

missing_values = churn_df.isnull().sum()
print(missing_values)
# Out:
# id                  0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
## check for duplicates
churn_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Drop Customer id column
churn_df.drop('id',axis=1,inplace=True)
churn_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      29          Yes
# 1    Male              0     Yes        Yes      58          Yes
# 2    Male              0     Yes         No      58          Yes
# 3  Female              0      No         No       1          Yes
# 4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1            No             DSL            Yes          Yes               No
# 2           Yes     Fiber optic             No          Yes               No
# 3            No     Fiber optic             No           No               No
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
churn_data = churn_df["Churn"].value_counts()

plt.pie(churn_data,labels=churn_data.index,autopct='%1.0f%%', colors=["blue", "red"])
plt.title('Churn Distribution')
plt.show()

# %%
churn_data
# Out:
# Churn
# No     460377
# Yes    133817
# Name: count, dtype: int64

# %% [markdown]
# ## Churn Distribution By Categorical and  Numerical features

# %%
## Encode Churn
churn_df['Churn']= churn_df['Churn'].map({
    'Yes': 1,
    'No': 0
})

# %%
## Churn distribution by Ctegorical Variables
categorical_cols = [
    'Contract',
    'PaymentMethod',
    'InternetService',
    'gender',
    'SeniorCitizen',
    'PhoneService'
]

# Create subplot grid
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Flatten axes for easy iteration
axes = axes.flatten()

for i, col in enumerate(categorical_cols):

    churn_rate = (
        churn_df.groupby(col)['Churn']
        .mean()
        .sort_values(ascending=False)
    )

    sns.barplot(
        x=churn_rate.index,
        y=churn_rate.values,
        ax=axes[i]
    )

    axes[i].set_title(f'Churn Rate by {col}')
    axes[i].set_ylabel("Churn Rate")
    axes[i].tick_params(axis='x', rotation=45)



plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = [
    'tenure',
    'MonthlyCharges',
    'TotalCharges'
]

# Create subplot grid
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Flatten axes
axes = axes.flatten()

for i, col in enumerate(numerical_cols):

    sns.kdeplot(
        data=churn_df,
        x=col,
        hue='Churn',
        fill=True,
        ax=axes[i]
    )

    axes[i].set_title(f'{col} Distribution by Churn')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Density")

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Separate the target from the features

# %%
X = churn_df.drop(columns=['Churn'])
y = churn_df['Churn']

# %% [markdown]
# ## Separate Columns by type

# %%
categorical_cols = X.select_dtypes(include=['object']).columns

numeric_cols = X.select_dtypes(exclude=['object']).columns

# %% [markdown]
# ## Preprocessing Pipeline

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Numeric Features

# %%
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %% [markdown]
# ## Categorical Features

# %%
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

## Combine features
preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_cols),
    ('cat', categorical_transformer, categorical_cols)
])

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# # Define Models

# %% [markdown]
# ## Logistic Regression

# %%
lr_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(max_iter=1000))
])

# %% [markdown]
# ## Random Forest

# %%
rf_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        random_state=42
    ))
])

# %% [markdown]
# ## XGBoost

# %%
xgb_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=6,
        random_state=42,
        eval_metric='logloss'
    ))
])

# %% [markdown]
# ## LightGBM

# %%
lgbm_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LGBMClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=6,
        random_state=42
    ))
])

# %% [markdown]
# ## Model Evaluation

# %%
def evaluate_model(name, model):

    model.fit(X_train, y_train)

    preds = model.predict(X_valid)

    probs = model.predict_proba(X_valid)[:,1]

    results = {
        'Model': name,
        'Accuracy': accuracy_score(y_valid, preds),
        'Precision': precision_score(y_valid, preds),
        'Recall': recall_score(y_valid, preds),
        'F1': f1_score(y_valid, preds),
        'ROC_AUC': roc_auc_score(y_valid, probs)
    }

    return results

# %% [markdown]
# ## Compare Models

# %%
results = pd.DataFrame([

    evaluate_model("Logistic Regression", lr_model),

    evaluate_model("Random Forest", rf_model),

    evaluate_model("XGBoost", xgb_model),

    evaluate_model("LightGBM", lgbm_model)

])

results.sort_values(by='ROC_AUC', ascending=False)
# Out:
# [LightGBM] [Info] Number of positive: 107054, number of negative: 368301
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040542 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 668
# [LightGBM] [Info] Number of data points in the train set: 475355, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.225209 -> initscore=-1.235567
# [LightGBM] [Info] Start training from score -1.235567
# C:\Users\TOM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ### Churn datasets are typically imbalanced and so is this one. Majority of the customers tend not to churn with only a significant small portion churning. Due to this imbalance, techniques such as under and oversampling, SMOTE(Synthetic Minority Oversampling) are used. To assess the viability of our model, accuracy isn't applicable as it's unreliable on imbalanced datasets. Metrics and methods such as precision, recall and f1-score will be used.

# %% [markdown]
# ## Predict Churn Probabilities

# %%
#xgb_model.fit(X, y)
xgb_model.fit(X_train, y_train)


test_probs = xgb_model.predict_proba(test_df)[:,1]

# %% [markdown]
# # Explainable AI using SHAP

# %% [markdown]
# ## SHAP (SHapley Additive exPlanations) explains:
#
# ### Why the model predicts churn
# ### Which features increase/decrease churn probability
# ### Global vs individual drivers of churn

# %% [markdown]
# ### Transform Validation Data

# %%
X_valid_transformed = (
    xgb_model.named_steps['preprocessor']
    .transform(X_valid)
)

# %% [markdown]
# ## Get Feature Names

# %%
feature_names = (
    xgb_model.named_steps['preprocessor']
    .get_feature_names_out()
)
## Covert to DataFrame
X_valid_shap = pd.DataFrame(
    X_valid_transformed,
    columns=feature_names
)

# %% [markdown]
# ## Extract rained Model

# %%
trained_xgb = xgb_model.named_steps['model']

## Sample Data for afster SHAP compuattion
X_sample = X_valid_shap.sample(
    500,
    random_state=42
)

# %% [markdown]
# ## Compute SHAP Values

# %%
## Create SHAP Explainer


explainer = shap.Explainer(
    trained_xgb.predict,
    X_sample
)


# Generate SHAP values
shap_values = explainer(X_sample)
# Out:
# PermutationExplainer explainer: 501it [01:09,  6.11it/s]

# %%
## Global Feature Importance

# %%
shap.plots.bar(shap_values)

plt.show()

# %%
Feature	Interpretation
tenure	strongest churn driver
low tenure customers push strongly toward churn
long-tenure customers reduce churn
Contract_Month-to-month	high churn risk
month-to-month contracts strongly increase churn risk
MonthlyCharges	pricing pressure
higher charges increase churn probability

# %% [markdown]
# ## Detailed Feature Impact

# %%
shap.plots.beeswarm(shap_values)

plt.show()

# %% [markdown]
# ## Dependence Plot

# %%
shap.plots.scatter(
    shap_values[:, "num__tenure"]
)

# %% [markdown]
# ## Waterfall Plot for Single Customer

# %%
shap.plots.waterfall(shap_values[0])

# %% [markdown]
# ## Create Submission File

# %%
submission = pd.DataFrame({
    'customerID': test['customerID'],
    'Churn_Probability': test_probs
})

submission.to_csv("submission.csv", index=False)

# %% [markdown]
# # Mutual Information Scores

# %%
X = df.copy()
y = X.pop("price")

# Label encoding for categoricals
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# All discrete features should now have integer dtypes (double-check this before using MI!)
discrete_features = X.dtypes == int

# %%
def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores[::3]  # show a few features with their MI scores

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)

# %%
sns.relplot(x="curb_weight", y="price", data=df);
